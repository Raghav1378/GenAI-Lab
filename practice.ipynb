# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
! uv pip install Pillow
# Out:
# Using Python 3.9.13 environment at: udemy
# Resolved 1 package in 388ms
# Installed 1 package in 319ms
#  + pillow==11.3.0

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="fal-ai",
    api_key=os.environ["HF_TOKEN"],
)

# output is a PIL.Image object
image = client.text_to_image(
    "Astronaut riding a horse",
    model="lightx2v/Qwen-Image-Lightning",
)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x768>

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="fal-ai",
    api_key=os.environ["HF_TOKEN"],
)

# output is a PIL.Image object
image = client.text_to_image(
    "Astronaut riding a horse",
    model="lightx2v/Qwen-Image-Lightning",
)

# %%
! uv pip install diffusers transformers accelerate safetensors torch torchvision
# Out:
# Using Python 3.9.13 environment at: udemy
# Audited 6 packages in 304ms
